# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd 
from preTrain import calWeight,MakeParams,getPreprocess
from sklearn.model_selection import StratifiedKFold
from trainer import trainer
from skopt import BayesSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from skopt.callbacks import DeltaYStopper
import pickle
import time

# %% [markdown]
# #### Import data

# %%
TRAINFILE="Data/train.csv"
TESTFILE="Data/test.csv"

trainDf=pd.read_csv(TRAINFILE)
validDf=pd.read_csv(TESTFILE)

keep_cols=['outcome','basegrd','baseucva','familyHistory','basesef','wearGlass']
cat_cols=['basegrd','familyHistory','basesef','wearGlass']

trainDf=trainDf[keep_cols]
validDf=validDf[keep_cols]

trainDf.dropna(axis=0,how='any',inplace=True)

# %% [markdown]
# #### Data split

# %%
Xtrain,ytrain=trainDf.iloc[:,1:],trainDf.iloc[:,0]

# %% [markdown]
# #### Preprocess

# %%
preprocessor=getPreprocess()

# %% [markdown]
# #### Fit model

# %%
models={}
models['cat']=CatBoostClassifier(eval_metric="BalancedAccuracy",cat_features=cat_cols)
models['ANN']=Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('ANN',MLPClassifier())
        ]
    )
models['Logistic']=Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('Logistic',LogisticRegression(max_iter=1000,solver='lbfgs',class_weight="balanced"))]
    )
models['rf']=RandomForestClassifier(class_weight="balanced_subsample")
models['xgb']=XGBClassifier(scale_pos_weight=calWeight(Xtrain,ytrain))
models['gbm']=LGBMClassifier(scale_pos_weight=calWeight(Xtrain,ytrain))
models['ada']=AdaBoostClassifier()
models['GB']=Pipeline(   steps=[
        ('preprocessor', preprocessor),
        ('GaussionNB',GaussianNB())]
)

# %%
params=MakeParams()
cv=StratifiedKFold(10,random_state=1234,shuffle=True)

# %%
optimizer_kwargs={
                  "base_estimator":"GBRT",
                  "n_initial_points":20,
                  "initial_point_generator":"random",
                  "acq_func":"LCB",
                  "acq_optimizer":"auto",
                  "n_jobs":-1,
                  "random_state":0,
                  "acq_func_kwargs": {"kappa":1.96}
                  }

# %%
mytrainer=trainer(models)
print(mytrainer)
mytrainer.setTrained({'GB':False})
# Out:
# Trainer中包含的模型是:['cat', 'ANN', 'Logistic', 'rf', 'xgb', 'gbm', 'ada', 'GB']
# GB已经设置为不进行超参数搜索!

# %%
mytrainer.setup(BayesSearchCV,params,cv=cv,scoring="balanced_accuracy",verbose=6,n_jobs=-1,n_iter=50,
                optimizer_kwargs=optimizer_kwargs)
mytrainer.fit(Xtrain,ytrain,callback=[DeltaYStopper(0.01,10)])
# Out:
# 共有7个模型,开始训练1个,模型是cat...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# 0:	learn: 0.8054660	total: 189ms	remaining: 33.9s
# 1:	learn: 0.8054824	total: 223ms	remaining: 19.9s
# 2:	learn: 0.8244476	total: 254ms	remaining: 15s
# 3:	learn: 0.8274480	total: 289ms	remaining: 12.7s
# 4:	learn: 0.8321969	total: 309ms	remaining: 10.8s
# 5:	learn: 0.8322018	total: 343ms	remaining: 9.94s
# 6:	learn: 0.8323492	total: 374ms	remaining: 9.24s
# 7:	learn: 0.8323492	total: 406ms	remaining: 8.74s
# 8:	learn: 0.8321605	total: 428ms	remaining: 8.13s
# 9:	learn: 0.8321605	total: 461ms	remaining: 7.83s
# 150:	learn: 0.8345499	total: 5.23s	remaining: 1s
# 151:	learn: 0.8345548	total: 5.27s	remaining: 970ms
# 152:	learn: 0.8345674	total: 5.3s	remaining: 936ms
# 153:	learn: 0.8345548	total: 5.34s	remaining: 901ms
# 154:	learn: 0.8345548	total: 5.37s	remaining: 867ms
# 155:	learn: 0.8343297	total: 5.41s	remaining: 833ms
# 156:	learn: 0.8343236	total: 5.45s	remaining: 798ms
# 157:	learn: 0.8343236	total: 5.48s	remaining: 763ms
# 158:	learn: 0.8343236	total: 5.52s	remaining: 729ms
# 159:	learn: 0.8344177	total: 5.56s	remaining: 696ms
# 160:	learn: 0.8344177	total: 5.6s	remaining: 661ms
# 161:	learn: 0.8344177	total: 5.64s	remaining: 627ms
# 162:	learn: 0.8344177	total: 5.67s	remaining: 592ms
# 163:	learn: 0.8344177	total: 5.71s	remaining: 557ms
# 164:	learn: 0.8344177	total: 5.75s	remaining: 523ms
# 165:	learn: 0.8344177	total: 5.79s	remaining: 488ms
# 166:	learn: 0.8344177	total: 5.82s	remaining: 453ms
# 167:	learn: 0.8344177	total: 5.86s	remaining: 418ms
# 168:	learn: 0.8344177	total: 5.89s	remaining: 384ms
# 169:	learn: 0.8344177	total: 5.93s	remaining: 349ms
# 170:	learn: 0.8344079	total: 5.97s	remaining: 314ms
# 171:	learn: 0.8344079	total: 6s	remaining: 279ms
# 172:	learn: 0.8344079	total: 6.04s	remaining: 244ms
# 173:	learn: 0.8344362	total: 6.08s	remaining: 210ms
# 174:	learn: 0.8344477	total: 6.12s	remaining: 175ms
# 175:	learn: 0.8344379	total: 6.16s	remaining: 140ms
# 176:	learn: 0.8344379	total: 6.2s	remaining: 105ms
# 177:	learn: 0.8344379	total: 6.24s	remaining: 70.1ms
# 178:	learn: 0.8344379	total: 6.28s	remaining: 35.1ms
# 179:	learn: 0.8344379	total: 6.31s	remaining: 0us
# 共有7个模型,开始训练2个,模型是ANN...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# 共有7个模型,开始训练3个,模型是Logistic...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# 共有7个模型,开始训练4个,模型是rf...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# 共有7个模型,开始训练5个,模型是xgb...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# 共有7个模型,开始训练6个,模型是gbm...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [LightGBM] [Info] Number of positive: 7193, number of negative: 304413
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006454 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44
# [LightGBM] [Info] Number of data points in the train set: 311606, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.023084 -> initscore=-3.745277
# [LightGBM] [Info] Start training from score -3.745277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 共有7个模型,开始训练7个,模型是ada...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits

# %%
mytrainer.save_model(file=f'Model_{int(time.time())}.pkl')

# %%
mytrainer.get_best_score()
# Out:
# {'cat': 0.832512133751073,
#  'ANN': 0.5000914496334639,
#  'Logistic': 0.8327342302028704,
#  'rf': 0.8332085382157354,
#  'xgb': 0.8287023226406859,
#  'gbm': 0.8331775682795708,
#  'ada': 0.5}

# %% [markdown]
# #### Save data

# %%
Xtrain.to_pickle("./Data/XtrainForModel.pkl")
ytrain.to_pickle("./Data/ytrainForModel.pkl")
validDf.to_pickle("./Data/validForModel.pkl")

# %% [markdown]
# #### Export the model

# %%
mytrainer=trainer.load_model("./Model_1708489668.pkl")
catboost=mytrainer.get_best_estimator()['cat']

# %%
catboost.save_model("./shinyapp/catboost")
